# %% [markdown]
# <a href="https://colab.research.google.com/github/sreent/machine-learning/blob/main/Linear%20Regression/22%20Linear%20Regression%20Warnings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression Warnings
#
# Linear regression comes with a set of implicit assumptions and is not the best model for every situation. Here are a couple of issues that you should watch out for.
#
# **Linear Regression Works Best When the Data is Linear** Linear regression produces a straight line model from the training data. If the relationship in the training data is not really linear, you'll need to either make adjustments (transform your training data), add features (we'll come to this next), or use another kind of model.
#
# ![image.png](data:image/png;base64,...)
#
# **Linear Regression is Sensitive to Outliers**
# Linear regression tries to find a 'best fit' line among the training data. If your dataset has some outlying extreme values that don't fit a general pattern, they can have a surprisingly large effect.
#
# In this first plot, the model fits the data pretty well.
#
# ![image.png](data:image/png;base64,...)
#
# However, adding a few points that are outliers and don't fit the pattern really changes the way the model predicts.
#
# ![image.png](data:image/png;base64,...)
#
# In most circumstances, you'll want a model that fits most of the data most of the time, so watch out for outliers!

# %% [markdown]
# ## Quiz Question
#
# Which of the following could be appropriate scenarios for linear regression and which are not?
#
# - Finding clusters of customers who reserve an Uber in the evening.
# - Predicting the best stock price for an IPO
# - Deciding if an email is SPAM or not.
# - Predicting the cost of college tuition for a new college in a new city
