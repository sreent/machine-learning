# %% [markdown]
# <a href="https://colab.research.google.com/github/sreent/machine-learning/blob/main/Model%20Evaluation%20Metrics/2%20Quiz%3A%20Testing%20Your%20Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import statements
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
# URL for our dataset, data.csv
URL = "https://drive.google.com/file/d/1SJVKhCW-oHfsQDCbOqca-eW4tnNKfFHC/view?usp=sharing"
FILE_PATH = "https://drive.google.com/uc?export=download&id=" + URL.split("/")[-2]

# Read the data.
data = np.asarray(pd.read_csv(FILE_PATH, header=None))

# Assign the features to the variable X, and the labels to the variable y.
X = None
y = None

# %%
# Use train test split to split your data
# Use a test size of 25% and a random state of 42
X_train, X_test, y_train, y_test = None

# %%
# TODO: Create the decision tree model and assign it to the variable model.
model = None

# TODO: Fit the model to the training data.
model.fit(None, None)

# TODO: Make predictions on the test data
y_pred = model.predict(None)

# TODO: Calculate the accuracy and assign it to the variable acc. on the test data
acc = accuracy_score(None, None)
acc
